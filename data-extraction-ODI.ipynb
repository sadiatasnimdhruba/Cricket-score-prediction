# %%
import numpy as np
import json, pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm
from pandas.io.json import json_normalize

# %%
# using os model extrat all files
filenames = []
for file in os.listdir('C:\\Users\\User\\Desktop\\OneDay_Data'):
    filenames.append(os.path.join('C:\\Users\\User\\Desktop\\OneDay_Data',file))

# %%
filenames[0:5]
# Out:
# ['C:\\Users\\User\\Desktop\\OneDay_Data\\1000887.yaml',
#  'C:\\Users\\User\\Desktop\\OneDay_Data\\1000889.yaml',
#  'C:\\Users\\User\\Desktop\\OneDay_Data\\1000891.yaml',
#  'C:\\Users\\User\\Desktop\\OneDay_Data\\1000893.yaml',
#  'C:\\Users\\User\\Desktop\\OneDay_Data\\1000895.yaml']

# %%
#use safe load for handling yaml
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r',encoding='UTF-8') as f:
        df = pd.json_normalize(safe_load(f))
        #df= pd.Dataframe(safe_load(f))
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
        
final_df
# Out:
#   0%|                                                                                         | 0/2034 [00:00<?, ?it/s]C:\Users\User\AppData\Local\Temp\ipykernel_4984\1995576707.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|                                                                               | 1/2034 [00:02<1:27:39,  2.59s/it]C:\Users\User\AppData\Local\Temp\ipykernel_4984\1995576707.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# ...

# %%
backup = final_df.copy()

# %%
final_df1 = backup.copy()

# %%
final_df1.columns.values
# Out:
# array(['innings', 'meta.data_version', 'meta.created', 'meta.revision',
#        'info.city', 'info.dates', 'info.gender', 'info.match_type',
#        'info.outcome.by.runs', 'info.outcome.winner', 'info.overs',
#        'info.player_of_match', 'info.teams', 'info.toss.decision',
#        'info.toss.winner', 'info.umpires', 'info.venue', 'match_id',
#        'info.outcome.by.wickets', 'info.outcome.result',
#        'info.outcome.method', 'info.neutral_venue',
#        'info.match_type_number', 'info.outcome.eliminator',
#        'info.supersubs.Australia', 'info.supersubs.England',
#        'info.supersubs.Africa XI', 'info.supersubs.Asia XI',
#        'info.supersubs.Zimbabwe', 'info.supersubs.Sri Lanka',
#        'info.supersubs.Bangladesh', 'info.supersubs.New Zealand',
#        'info.supersubs.India', 'info.supersubs.ICC World XI',
#        'info.supersubs.South Africa', 'info.supersubs.Pakistan',
#        'info.supersubs.West Indies'], dtype=object)

# %%
final_df1.drop(columns=[
       'meta.data_version', 'meta.created', 'meta.revision',
       'info.outcome.by.runs',         
       'info.outcome.by.wickets', 'info.outcome.result',
       'info.outcome.method', 'info.neutral_venue',
       'info.match_type_number', 'info.outcome.eliminator',
       'info.supersubs.Australia', 'info.supersubs.England',
       'info.supersubs.Africa XI', 'info.supersubs.Asia XI',
       'info.supersubs.Zimbabwe', 'info.supersubs.Sri Lanka',
       'info.supersubs.Bangladesh', 'info.supersubs.New Zealand',
       'info.supersubs.India', 'info.supersubs.ICC World XI',
       'info.supersubs.South Africa', 'info.supersubs.Pakistan',
       'info.supersubs.West Indies']
,inplace=True)

# %%
final_df1
# Out:
#                                               innings  info.city  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...   Brisbane
# 0   [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...      Perth
# 0   [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 0   [{'1st innings': {'team': 'Australia', 'delive...        NaN
# ..                                                ...        ...
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...    Belfast
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...  Edinburgh
# 0   [{'1st innings': {'team': 'United Arab Emirate...  Edinburgh
#
#       info.dates info.gender info.match_type info.outcome.winner  info.overs  \
# 0   [2017-01-13]        male             ODI           Australia          50
# ...

# %%
# to show the no of male and felame matches
final_df1['info.gender'].value_counts()
# Out:
# male      1799
# female     234
# Name: info.gender, dtype: int64

# %%
#only keep the male info
final_df1 = final_df1[final_df1['info.gender'] == 'male']
final_df1.drop(columns=['info.gender'],inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4984\2292410662.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df1.drop(columns=['info.gender'],inplace=True)

# %%
final_df1
# Out:
#                                               innings  info.city  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...   Brisbane
# 0   [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...      Perth
# 0   [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 0   [{'1st innings': {'team': 'Australia', 'delive...        NaN
# ..                                                ...        ...
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...    Belfast
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...  Edinburgh
# 0   [{'1st innings': {'team': 'United Arab Emirate...  Edinburgh
#
#       info.dates info.match_type info.outcome.winner  info.overs  \
# 0   [2017-01-13]             ODI           Australia          50
# ...

# %%
#concentrate only for ODI match here
final_df1['info.match_type'].value_counts()
# Out:
# ODI    1799
# Name: info.match_type, dtype: int64

# %%
final_df1['info.overs'].value_counts()
# Out:
# 50    1799
# Name: info.overs, dtype: int64

# %%
import pickle
from io import open
#f = open("dataset_lev1.pkl", mode="wb")
pickle.dump(final_df1,open('dataset_lev1.pkl','wb'))

# %%
#f = open('dataset_lev1.pkl', 'rb')
matches = pickle.load(open('dataset_lev1.pkl', 'rb'))

# %%
matches
# Out:
#                                               innings  info.city  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...   Brisbane
# 0   [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...      Perth
# 0   [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 0   [{'1st innings': {'team': 'Australia', 'delive...        NaN
# ..                                                ...        ...
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 0   [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...    Belfast
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...  Edinburgh
# 0   [{'1st innings': {'team': 'United Arab Emirate...  Edinburgh
#
#       info.dates info.match_type info.outcome.winner  info.overs  \
# 0   [2017-01-13]             ODI           Australia          50
# ...

# %%
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.3: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.4: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.5: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'extras': {'wides': 1},
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {0.6: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.7: {'batsman': 'DA Warner',
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4984\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\User\AppData\Local\Temp\ipykernel_4984\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\User\AppData\Local\Temp\ipykernel_4984\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\User\AppData\Local\Temp\ipykernel_4984\3780558368.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# ...

# %%
delivery_df
# Out:
#      match_id                             teams          batting_team  ball  \
# 0           2             [Australia, Pakistan]             Australia   0.1
# 1           2             [Australia, Pakistan]             Australia   0.2
# 2           2             [Australia, Pakistan]             Australia   0.3
# 3           2             [Australia, Pakistan]             Australia   0.4
# 4           2             [Australia, Pakistan]             Australia   0.5
# ..        ...                               ...                   ...   ...
# 281      1800  [Scotland, United Arab Emirates]  United Arab Emirates  44.6
# 282      1800  [Scotland, United Arab Emirates]  United Arab Emirates  45.1
# 283      1800  [Scotland, United Arab Emirates]  United Arab Emirates  45.2
# 284      1800  [Scotland, United Arab Emirates]  United Arab Emirates  45.3
# 285      1800  [Scotland, United Arab Emirates]  United Arab Emirates  45.4
#
# ...

# %%
#extract bowling team
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
#data with bowling team
delivery_df
# Out:
#      match_id                             teams          batting_team  ball  \
# 0           2             [Australia, Pakistan]             Australia   0.1
# 1           2             [Australia, Pakistan]             Australia   0.2
# 2           2             [Australia, Pakistan]             Australia   0.3
# 3           2             [Australia, Pakistan]             Australia   0.4
# 4           2             [Australia, Pakistan]             Australia   0.5
# ..        ...                               ...                   ...   ...
# 281      1800  [Scotland, United Arab Emirates]  United Arab Emirates  44.6
# 282      1800  [Scotland, United Arab Emirates]  United Arab Emirates  45.1
# 283      1800  [Scotland, United Arab Emirates]  United Arab Emirates  45.2
# 284      1800  [Scotland, United Arab Emirates]  United Arab Emirates  45.3
# 285      1800  [Scotland, United Arab Emirates]  United Arab Emirates  45.4
#
# ...

# %%
#as batting and bowling teams are seperated we can drop teams
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df
# Out:
#      match_id          batting_team  ball       batsman         bowler  runs  \
# 0           2             Australia   0.1     DA Warner  Mohammad Amir     0
# 1           2             Australia   0.2     DA Warner  Mohammad Amir     0
# 2           2             Australia   0.3     DA Warner  Mohammad Amir     0
# 3           2             Australia   0.4     DA Warner  Mohammad Amir     0
# 4           2             Australia   0.5     DA Warner  Mohammad Amir     1
# ..        ...                   ...   ...           ...            ...   ...
# 281      1800  United Arab Emirates  44.6    Ahmed Raza        CB Sole     0
# 282      1800  United Arab Emirates  45.1  Fayyaz Ahmed       AC Evans     1
# 283      1800  United Arab Emirates  45.2    Ahmed Raza       AC Evans     0
# 284      1800  United Arab Emirates  45.3    Ahmed Raza       AC Evans     0
# 285      1800  United Arab Emirates  45.4    Ahmed Raza       AC Evans     0
#
# ...

# %%
delivery_df['batting_team'].unique()
#check unique countries
# Out:
# array(['Australia', 'Pakistan', 'Afghanistan', 'Scotland', 'Zimbabwe',
#        'New Zealand', 'Bangladesh', 'South Africa', 'India', 'England',
#        'Sri Lanka', 'Hong Kong', 'Papua New Guinea', 'West Indies',
#        'Ireland', 'United Arab Emirates', 'Nepal',
#        'United States of America', 'Namibia', 'Oman', 'Africa XI',
#        'Kenya', 'Bermuda', 'Netherlands', 'Canada', 'Asia XI'],
#       dtype=object)

# %%
teams = [
    'Australia',
    'India',
    'Zimbabwe',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#      match_id batting_team  ball       batsman         bowler  runs  \
# 0           2    Australia   0.1     DA Warner  Mohammad Amir     0
# 1           2    Australia   0.2     DA Warner  Mohammad Amir     0
# 2           2    Australia   0.3     DA Warner  Mohammad Amir     0
# 3           2    Australia   0.4     DA Warner  Mohammad Amir     0
# 4           2    Australia   0.5     DA Warner  Mohammad Amir     1
# ..        ...          ...   ...           ...            ...   ...
# 244      1795    Sri Lanka  39.5  SS Pathirana       MA Starc     0
# 245      1795    Sri Lanka  39.6  SS Pathirana       MA Starc     0
# 246      1795    Sri Lanka  39.7  SS Pathirana       MA Starc     1
# 247      1795    Sri Lanka  40.1  SS Pathirana      SM Boland     0
# 248      1795    Sri Lanka  40.2  SS Pathirana      SM Boland     0
#
#     player_dismissed      city                                    venue  \
# 0                  0  Brisbane   Brisbane Cricket Ground, Woolloongabba
# ...

# %%
#now we will create a new data frame
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia     Pakistan   0.1     0                0
# 1           2    Australia     Pakistan   0.2     0                0
# 2           2    Australia     Pakistan   0.3     0                0
# 3           2    Australia     Pakistan   0.4     0                0
# 4           2    Australia     Pakistan   0.5     1                0
# ..        ...          ...          ...   ...   ...              ...
# 244      1795    Sri Lanka    Australia  39.5     0                0
# 245      1795    Sri Lanka    Australia  39.6     0                0
# 246      1795    Sri Lanka    Australia  39.7     1                0
# 247      1795    Sri Lanka    Australia  40.1     0                0
# 248      1795    Sri Lanka    Australia  40.2     0     SS Pathirana
#
#          city                                    venue
# 0    Brisbane   Brisbane Cricket Ground, Woolloongabba
# ...

# %%
#then dump some data using pickle
#f2 = open("dataset_lev2.pkl", mode="w", encoding="utf-8")
pickle.dump(output,open('dataset_lev2.pkl','wb'))
