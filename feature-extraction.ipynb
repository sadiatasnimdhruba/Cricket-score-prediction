# %%
import pandas as pd
import pickle
import numpy as np

# %%
#we will open level-2 file
#f = open("dataset_level2.pkl", mode="r", encoding="utf-8")
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df

# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       964    Sri Lanka    Australia  19.3     1                0  Colombo
# 122       964    Sri Lanka    Australia  19.4     0                0  Colombo
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       964    Sri Lanka    Australia  19.6     2                0  Colombo
# 125       964    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# ...

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
#in 8548 rows values are missing. In those rows value of cities are missing
df['city'].isnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 121    False
# 122    False
# 123    False
# 124    False
# 125    False
# Name: city, Length: 63888, dtype: bool

# %%
#to solve problem we will use venue
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
#if the city value is empty, then it will be replaced by the 1st letter of venue
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
#then drop the venue
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %%
df['city'].value_counts()
# Out:
# Colombo          4086
# Mirpur           3420
# Johannesburg     3331
# Dubai            2969
# Auckland         2532
#                  ...
# Nairobi           123
# Potchefstroom     122
# Dharamsala        122
# Ahmedabad         121
# Carrara            64
# Name: city, Length: 86, dtype: int64

# %%
#there are 86 cities, but we will not consider all. we will consider where minimum 5 matches occur.
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
#now we will keep the data of eligable cities
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %%
#now we will focus on current score 
df.groupby('match_id').cumsum()['runs']
# Out:
# 0        0
# 1        0
# 2        1
# 3        3
# 4        3
#       ...
# 121    125
# 122    125
# 123    125
# 124    127
# 125    128
# Name: runs, Length: 50501, dtype: int64

# %%
#then we will put it in new column named current score
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15020\4127419751.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score
# 0    Melbourne              0
# 1    Melbourne              0
# 2    Melbourne              1
# ...

# %%
#then we will work on ball column. 0.1 means over=0 and ball=1. so we will seperate over and ball column
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15020\2015637041.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\User\AppData\Local\Temp\ipykernel_15020\2015637041.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no
# 0    Melbourne              0    0       1
# 1    Melbourne              0    0       2
# ...

# %%
#then calculate bowled balls
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15020\1276871035.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled
# 0    Melbourne              0    0       1             1
# ...

# %%
#calculate how many balls are left
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15020\3434793044.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\User\AppData\Local\Temp\ipykernel_15020\3434793044.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0    Melbourne              0    0       1             1         119
# ...

# %%
#then work on wicket left. if the playes_dismissed value = 0, we will keep 0 else 1. then calculate cumulative sum. then subtract from 10
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15020\4088362777.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# C:\Users\User\AppData\Local\Temp\ipykernel_15020\4088362777.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# C:\Users\User\AppData\Local\Temp\ipykernel_15020\4088362777.py:4: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
#calculate current run rate using current score and balls_bowled
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15020\2710979754.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
#calculate the score of last 5 overs. here we use rolling function. 1st divide the data frame into groups using match_id
#then run a loop. 
#window=30, cz last 5 overs 6*5=30 balls
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15020\1698907277.py:9: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
last_five #here 1 st 30 values are missing
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  43.0,
#  44.0,
#  45.0,
#  44.0,
#  42.0,
#  43.0,
#  41.0,
#  41.0,
#  41.0,
#  42.0,
#  42.0,
#  39.0,
#  38.0,
#  39.0,
#  38.0,
#  39.0,
#  40.0,
#  37.0,
#  41.0,
#  42.0,
#  42.0,
#  44.0,
#  44.0,
#  40.0,
#  39.0,
#  37.0,
#  35.0,
#  31.0,
#  27.0,
#  26.0,
#  31.0,
#  31.0,
#  30.0,
#  31.0,
#  31.0,
#  32.0,
#  31.0,
#  31.0,
#  36.0,
#  37.0,
#  37.0,
#  37.0,
#  37.0,
#  36.0,
#  36.0,
#  36.0,
#  36.0,
#  35.0,
#  32.0,
#  32.0,
#  31.0,
#  29.0,
#  29.0,
#  31.0,
#  32.0,
#  32.0,
#  32.0,
#  33.0,
#  36.0,
#  37.0,
#  37.0,
#  39.0,
#  41.0,
#  40.0,
#  41.0,
#  41.0,
#  42.0,
#  44.0,
#  39.0,
#  43.0,
#  45.0,
#  48.0,
#  48.0,
#  48.0,
#  49.0,
#  49.0,
#  49.0,
#  51.0,
#  51.0,
#  51.0,
#  52.0,
#  52.0,
#  53.0,
#  53.0,
#  53.0,
# ...

# %%
df['last_five'] = last_five
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15020\786792159.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
#calculate final score
df.groupby('match_id').sum()['runs']
# Out:
# match_id
# 2      168
# 4      187
# 10     195
# 11     194
# 12     185
#       ...
# 958    129
# 960    150
# 961    120
# 963    263
# 964    128
# Name: runs, Length: 416, dtype: int64

# %%
df.groupby('match_id').sum()['runs'].reset_index()
# Out:
#      match_id  runs
# 0           2   168
# 1           4   187
# 2          10   195
# 3          11   194
# 4          12   185
# ..        ...   ...
# 411       958   129
# 412       960   150
# 413       961   120
# 414       963   263
# 415       964   128
#
# [416 rows x 2 columns]

# %%
df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')
# Out:
#        match_id  runs_x batting_team bowling_team  ball  runs_y  \
# 0             2     168    Australia    Sri Lanka   0.1       0
# 1             2     168    Australia    Sri Lanka   0.2       0
# 2             2     168    Australia    Sri Lanka   0.3       1
# 3             2     168    Australia    Sri Lanka   0.4       2
# 4             2     168    Australia    Sri Lanka   0.5       0
# ...         ...     ...          ...          ...   ...     ...
# 50496       964     128    Sri Lanka    Australia  19.3       1
# 50497       964     128    Sri Lanka    Australia  19.4       0
# 50498       964     128    Sri Lanka    Australia  19.5       0
# 50499       964     128    Sri Lanka    Australia  19.6       2
# 50500       964     128    Sri Lanka    Australia  19.7       1
#
#        player_dismissed       city  current_score over ball_no  balls_bowled  \
# 0                     0  Melbourne              0    0       1             1
# ...

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Australia    Sri Lanka  Melbourne              0         119
# 1        Australia    Sri Lanka  Melbourne              0         118
# 2        Australia    Sri Lanka  Melbourne              1         117
# 3        Australia    Sri Lanka  Melbourne              3         116
# 4        Australia    Sri Lanka  Melbourne              3         115
# ...            ...          ...        ...            ...         ...
# 50496    Sri Lanka    Australia    Colombo            125           3
# 50497    Sri Lanka    Australia    Colombo            125           2
# 50498    Sri Lanka    Australia    Colombo            125           1
# 50499    Sri Lanka    Australia    Colombo            127           0
# 50500    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 0                10  0.000000        NaN     168
# ...

# %%
#then drop the missing values
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12024
# runs_x               0
# dtype: int64

# %%
#as 12024 values are missing
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
#now no values will be missed
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 29       Australia    Sri Lanka  Melbourne             43          90
# 30       Australia    Sri Lanka  Melbourne             44          89
# 31       Australia    Sri Lanka  Melbourne             45          88
# 32       Australia    Sri Lanka  Melbourne             45          87
# 33       Australia    Sri Lanka  Melbourne             45          86
# ...            ...          ...        ...            ...         ...
# 50496    Sri Lanka    Australia    Colombo            125           3
# 50497    Sri Lanka    Australia    Colombo            125           2
# 50498    Sri Lanka    Australia    Colombo            125           1
# 50499    Sri Lanka    Australia    Colombo            127           0
# 50500    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 29               10  8.600000       43.0     168
# ...

# %%
#for shuffling
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#       batting_team bowling_team         city  current_score  balls_left  \
# 33040     Pakistan        India      Colombo             73          50
# 12641    Sri Lanka     Pakistan       Lahore            135          31
# 39406     Pakistan    Australia       Mirpur            144          29
# 14379    Sri Lanka      England  Southampton            110          43
# 44114     Pakistan    Sri Lanka      Colombo             46          80
# ...            ...          ...          ...            ...         ...
# 45311      England     Pakistan        Dubai            168           1
# 49244        India  West Indies       Mumbai             68          68
# 5697    Bangladesh        India      Colombo            100          31
# 18692      England  New Zealand     Auckland             92          56
# 7448     Australia        India       Sydney            145           8
#
#        wickets_left       crr  last_five  runs_x
# 33040             5  6.257143       30.0     128
# ...

# %%
final_df.sample(2)
# Out:
#       batting_team bowling_team      city  current_score  balls_left  \
# 10332        India   Bangladesh    Nagpur             53          73
# 24757    Australia        India  Barbados             76          66
#
#        wickets_left       crr  last_five  runs_x
# 10332             8  6.765957       40.0     174
# 24757            10  8.444444       41.0     184

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team  bowling_team        city  current_score  balls_left  \
# 40229  South Africa       England  Chittagong             53          83
# 5722     Bangladesh         India     Colombo            126          10
# 33264     Sri Lanka       England   Pallekele             57          72
# 34692   West Indies   New Zealand  Lauderhill             65          62
# 33505         India  South Africa     Colombo             45          77
# ...             ...           ...         ...            ...         ...
# 19940         India    Bangladesh  Nottingham             60          75
# 33205   West Indies   New Zealand   Pallekele            135          11
# 23435   New Zealand     Sri Lanka     Colombo            109          43
# 34259      Pakistan    Bangladesh      Mirpur            130           1
# 2899     Bangladesh     Sri Lanka     Colombo             58          87
#
#        wickets_left        crr  last_five
# 40229            10   8.594595       41.0
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9880679091610333
# 1.6005190752152345

# %%
#export it
#f = open("pipe.pkl", mode="w", encoding="utf-8")
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import xgboost
xgboost.__version__
# Out:
# '1.6.0'
